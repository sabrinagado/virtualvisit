# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

pd.options.mode.chained_assignment = None

# %%
from Code import plot_gaze

# %% [markdown]
# ## Set Paths and Parameters

# %%
# ToDo: Adapt wave and problematic subject list
wave = 2
if wave == 1:
    problematic_subjects = [1, 3, 12, 19, 33, 45, 46]
elif wave == 2:
    problematic_subjects = [1, 2, 3, 4, 20, 29, 64]

# %%
dir_path = os.getcwd()
dir_path = os.path.abspath(os.path.join(dir_path, os.pardir))
# ToDo: Adapt folder name
file_path = os.path.join(dir_path, f'Data-Wave{wave}')

# %%
SA_score="SPAI"

# %%
df_scores = pd.read_csv(os.path.join(file_path, 'scores_summary.csv'), decimal='.', sep=';')
df_ratings = pd.read_csv(os.path.join(file_path, 'ratings.csv'), decimal='.', sep=';')

# %% [markdown]
# ## Gaze

# %%
df_gaze = pd.read_csv(os.path.join(file_path, 'gaze.csv'), decimal='.', sep=';')

# %%
save_path = os.path.join(dir_path, f'Plots-Wave{wave}',  'Gaze')
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
# ToDo: Adapt dependent variable
dvs = ["Gaze Proportion", "Switches"]
dv = dvs[0]

# %%
# plot_gaze.plot_gaze(df_gaze, save_path, dv=dv, SA_score=SA_score)

# %% [markdown]
# ### Acquisition Phase

# %%
phase = "Acquisition"
plot_gaze.plot_gaze_phase(df_gaze, save_path, phase=phase, dv=dv, SA_score=SA_score, only_head=False)
plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}.png"), dpi=300)
plot_gaze.plot_gaze_phase(df_gaze, save_path, phase=phase, dv=dv, SA_score=SA_score, only_head=True)
plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}_head.png"), dpi=300)

plot_gaze.plot_gaze_sad(df_gaze, phase=phase, dv=dv, SA_score=SA_score, only_head=True)
plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}_{SA_score}.png"), dpi=300)

plot_gaze.plot_gaze_roi(df_gaze, phase=phase, dv=dv, SA_score=SA_score)
plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}_roi.png"), dpi=300, bbox_inches="tight")

# plot_gaze.plot_gaze_roi_sad(df_gaze, save_path, phase=phase, dv=dv, SA_score=SA_score)
# plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}_{SA_score}_roi.png"), dpi=300)
# Out:
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
#
# boundary (singular) fit: see help('isSingular')
#
# SS Type III Analysis of Variance Table with Satterthwaite approximated degrees of freedom:
# (NOTE: Model refit with orthogonal polynomial contrasts)
# SS Type III Analysis of Variance Table with Satterthwaite approximated degrees of freedom:
# (NOTE: Model refit with orthogonal polynomial contrasts)
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
#
# boundary (singular) fit: see help('isSingular')
#
# SS Type III Analysis of Variance Table with Satterthwaite approximated degrees of freedom:
# (NOTE: Model refit with orthogonal polynomial contrasts)
# P-values adjusted by holm method for 1 comparisons

# %% [markdown]
# ### Test Phase

# %%
phase = "Test"
plot_gaze.plot_gaze_phase(df_gaze, save_path, phase=phase, dv=dv, SA_score=SA_score, only_head=False)
plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}.png"), dpi=300)
plot_gaze.plot_gaze_phase(df_gaze, save_path, phase=phase, dv=dv, SA_score=SA_score, only_head=True)
plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}_head.png"), dpi=300)

plot_gaze.plot_gaze_sad(df_gaze, phase=phase, dv=dv, SA_score=SA_score, only_head=False)
plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}_{SA_score}.png"), dpi=300)

plot_gaze.plot_gaze_roi(df_gaze, phase=phase, dv=dv, SA_score=SA_score)
plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}_roi.png"), dpi=300, bbox_inches="tight")

# plot_gaze.plot_gaze_roi_sad(df_gaze, save_path, phase=phase, dv=dv, SA_score=SA_score)
# plt.savefig(os.path.join(save_path, f"gaze_{phase.lower()}_{dv.replace(' ', '_').lower()}_{SA_score}_roi.png"), dpi=300)
# Out:
# SS Type III Analysis of Variance Table with Satterthwaite approximated degrees of freedom:
# (NOTE: Model refit with orthogonal polynomial contrasts)
# SS Type III Analysis of Variance Table with Satterthwaite approximated degrees of freedom:
# (NOTE: Model refit with orthogonal polynomial contrasts)
# SS Type III Analysis of Variance Table with Satterthwaite approximated degrees of freedom:
# (NOTE: Model refit with orthogonal polynomial contrasts)
# P-values adjusted by holm method for 1 comparisons
